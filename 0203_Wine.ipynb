# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
cd input
# Out:
# [WinError 2] 指定されたファイルが見つかりません。: 'input'
# D:\python学習\GCI2019\competition2\input

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            9.8              0.63         0.24             2.4      0.078
# 1            6.1              0.34         0.25             1.8      0.084
# 2            7.1              0.43         0.17             1.8      0.083
# 3            8.6              0.47         0.27             1.9      0.058
# 4            6.9              0.41         0.30             8.9      0.084
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  6.1                  32.6   0.9997  3.08       0.57
# 1                  4.0                  28.0   0.9941  3.36       0.44
# 2                 27.2                  51.3   0.9941  3.51       0.63
# 3                 17.5                  37.6   0.9907  3.16       0.85
# 4                 25.9                  45.4   0.9861  3.35       0.64
#
#    alcohol  quality
# 0      9.4      5.1
# 1     10.2      4.8
# 2     10.4      5.5
# 3     11.1      6.1
# 4     10.2      5.6

# %%
validPh = train[train['pH'].isnull()]

# %%
validPh.head()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 41             7.3              0.36         0.30             1.6      0.079
# 45             6.4              0.57         0.14             3.9      0.070
# 51            11.0              0.20         0.48             2.0      0.347
# 92             9.4              0.79         0.22             1.9      0.077
# 100           13.0              0.32         0.66             2.6      0.092
#
#      free sulfur dioxide  total sulfur dioxide  density  pH  sulphates  \
# 41                  35.0                  70.2   1.0031 NaN       0.50
# 45                  26.5                  73.0   1.0087 NaN       0.49
# 51                   6.0                  18.0   0.9998 NaN       0.71
# 92                   5.9                  32.1   1.0003 NaN       0.56
# 100                 15.1                  46.4   0.9922 NaN       0.62
#
#      alcohol  quality
# 41       9.5      5.4
# 45       9.1      5.2
# 51      10.5      4.9
# 92      10.5      5.3
# 100     10.6      5.1

# %%
valid_density = train[train['density'].isnull()]

# %%
valid_density.head()
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 13            6.1              0.21         0.40             1.4      0.066
# 18            6.9              0.63         0.02             2.1      0.067
# 21            6.2              0.59         0.10             1.6      0.048
# 23            6.3              0.41         0.09             2.3      0.054
# 26            6.0              0.50         0.00             2.1      0.064
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 13                 40.0                 165.1      NaN  3.24       0.58
# 18                  8.9                  23.1      NaN  3.45       0.68
# 21                 12.0                  26.3      NaN  3.56       0.51
# 23                 34.7                  63.2      NaN  3.47       0.69
# 26                 39.3                  52.8      NaN  3.46       0.94
#
#     alcohol  quality
# 13     11.8      5.9
# 18      9.4      6.4
# 21     12.1      4.6
# 23     10.4      5.5
# 26     10.7      6.8

# %%
rfr = RandomForestRegressor()

# %%
validPh.isnull().sum()
# Out:
# fixed acidity             0
# volatile acidity          0
# citric acid               0
# residual sugar            0
# chlorides                 0
# free sulfur dioxide       0
# total sulfur dioxide      0
# density                  13
# pH                      137
# sulphates                 0
# alcohol                   0
# quality                   0
# dtype: int64

# %%
train.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.257760     0.667667
# volatile acidity          -0.257760          1.000000    -0.558506
# citric acid                0.667667         -0.558506     1.000000
# residual sugar             0.126457         -0.006741     0.121092
# chlorides                  0.097590          0.047067     0.235658
# free sulfur dioxide       -0.164322          0.000769    -0.073109
# total sulfur dioxide      -0.121355          0.072490     0.025574
# density                    0.153865          0.037969     0.084490
# pH                        -0.652184          0.240934    -0.515231
# sulphates                  0.179797         -0.238319     0.315335
# alcohol                   -0.064596         -0.194433     0.109536
# quality                    0.122955         -0.322637     0.198189
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.126457   0.097590            -0.164322
# volatile acidity           -0.006741   0.047067             0.000769
# citric acid                 0.121092   0.235658            -0.073109
# residual sugar              1.000000   0.059375             0.197699
# chlorides                   0.059375   1.000000             0.018818
# free sulfur dioxide         0.197699   0.018818             1.000000
# total sulfur dioxide        0.200760   0.055482             0.664774
# density                     0.082197   0.022084             0.029391
# pH                         -0.087567  -0.279400             0.071753
# sulphates                   0.008727   0.408918             0.049267
# alcohol                     0.049476  -0.228481            -0.051931
# quality                     0.034671  -0.107576            -0.040533
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.121355  0.153865 -0.652184   0.179797
# volatile acidity                  0.072490  0.037969  0.240934  -0.238319
# citric acid                       0.025574  0.084490 -0.515231   0.315335
# residual sugar                    0.200760  0.082197 -0.087567   0.008727
# chlorides                         0.055482  0.022084 -0.279400   0.408918
# free sulfur dioxide               0.664774  0.029391  0.071753   0.049267
# total sulfur dioxide              1.000000  0.065429 -0.090332   0.059011
# density                           0.065429  1.000000 -0.082872   0.046434
# pH                               -0.090332 -0.082872  1.000000  -0.237210
# sulphates                         0.059011  0.046434 -0.237210   1.000000
# alcohol                          -0.190345 -0.093399  0.211401   0.060147
# quality                          -0.137093 -0.015096 -0.065055   0.192451
#
#                        alcohol   quality
# fixed acidity        -0.064596  0.122955
# volatile acidity     -0.194433 -0.322637
# citric acid           0.109536  0.198189
# residual sugar        0.049476  0.034671
# chlorides            -0.228481 -0.107576
# free sulfur dioxide  -0.051931 -0.040533
# total sulfur dioxide -0.190345 -0.137093
# density              -0.093399 -0.015096
# pH                    0.211401 -0.065055
# sulphates             0.060147  0.192451
# alcohol               1.000000  0.381478
# quality               0.381478  1.000000

# %%
pH_Data = validPh.fillna(validPh.mean())

# %%
pH_Data.isnull().sum()
# Out:
# fixed acidity             0
# volatile acidity          0
# citric acid               0
# residual sugar            0
# chlorides                 0
# free sulfur dioxide       0
# total sulfur dioxide      0
# density                   0
# pH                      137
# sulphates                 0
# alcohol                   0
# quality                   0
# dtype: int64
